# %%
def print_name():
    print("TIYA")

# %%
print_name()
# Out:
# TIYA

# %%
def print_name(a):
    print(f' HI, {a}')

# %%
print_name("TIYA")
# Out:
#  HI, TIYA

# %%
print_name("jack")
# Out:
#  HI, jack

# %%
def multi_arg(*arg):
    print(arg)

# %%
multi_arg(1,2,3)
# Out:
# (1, 2, 3)

# %%
def add(a,b,c):
    return a+b+c

# %%
add(1,3,1)
# Out:
# 5

# %%
def student(**info):
    for key, value in info.items():
        print(key, ":", value)

# %%
TIYA_details = student(name="TIYA", contact=212)
# Out:
# name : TIYA
# contact : 212

# %%
def myfunc(a,b):
    return a+b , a-b

# %%
myfunc(1,3)
# Out:
# (4, -2)

# %%
double = lambda x : x*2

# %%
print (double(6))
# Out:
# 12
